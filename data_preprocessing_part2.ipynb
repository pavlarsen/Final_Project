# %%
# Import dependencies
import pandas as pd
import numpy as np
from google.colab import files

# %%
# Load in the Country_Data Dataset
path = "https://raw.githubusercontent.com/pavlarsen/Final_Project/main/Resources/Data/Country_Data.csv"
country_data_df = pd.read_csv(path)
country_data_df.head(10)
# Out:
#    Row FIPS GENC Country/Area Name  Year  Area in Square Kilometers  \
# 0    1   AF   AF       Afghanistan  1990                     652230
# 1    2   AF   AF       Afghanistan  1995                     652230
# 2    3   AF   AF       Afghanistan  2000                     652230
# 3    4   AF   AF       Afghanistan  2005                     652230
# 4    5   AF   AF       Afghanistan  2010                     652230
# 5    6   AF   AF       Afghanistan  2015                     652230
# 6    7   AF   AF       Afghanistan  2020                     652230
# 7    8   AL   AL           Albania  1990                      27398
# 8    9   AL   AL           Albania  1995                      27398
# 9   10   AL   AL           Albania  2000                      27398
#
#    Population  Annual Growth Rate %  Rate of Natural Increase  \
# 0    13568282                -1.928                     3.194
# 1    19445013                 3.492                     3.224
# 2    22461349                -1.328                     3.202
# 3    26332646                 3.439                     2.496
# 4    29116851                 2.139                     2.464
# 5    32547550                 2.306                     2.456
# 6    36594776                 2.366                     2.376
# 7     3244925                 1.110                     1.971
# 8     3158153                 1.491                     1.712
# 9     3158351                -1.019                     1.104
#
#    Population Density (People per Sq. Km.)  Total Fertility Rate  \
# 0                                     20.8                8.0000
# 1                                     29.8                8.0000
# 2                                     34.4                8.0000
# 3                                     40.4                6.3707
# 4                                     44.6                5.8532
# 5                                     49.9                5.3260
# 6                                     56.1                4.8200
# 7                                    118.4                3.0884
# 8                                    115.3                2.9429
# 9                                    115.3                2.1716
#
#    Crude Birth Rate  Life Expectancy at Birth, Both Sexes  \
# 0             54.44                                 42.19
# 1             53.23                                 43.88
# 2             51.35                                 45.49
# 3             41.51                                 47.06
# 4             39.77                                 48.93
# 5             38.52                                 50.87
# 6             36.56                                 52.84
# 7             25.72                                 71.16
# 8             23.32                                 71.24
# 9             16.43                                 74.70
#
#    Infant Mortality Rate, Both Sexes  Crude Death Rate  Net Migration Rate
# 0                             167.73             22.50              -51.23
# 1                             156.75             20.99                2.68
# 2                             146.75             19.33              -45.30
# 3                             137.56             16.55                9.43
# 4                             127.79             15.13               -3.25
# 5                             118.07             13.96               -1.51
# 6                             108.64             12.80               -0.10
# 7                              44.28              6.01               -8.61
# 8                              50.50              6.20               -2.21
# 9                              22.62              5.39              -21.22

# %%
# Rename the columns we will use
country_data_df.rename(columns={"GENC": "Country_ID_Alpha", "Country/Area Name": "Country_Name", "Area in Square Kilometers":"Country_Area", "Population":"Total_Country_Population","Annual Growth Rate %":"Annual_Growth_Rate", "Population Density (People per Sq. Km.)":"Population_Density", "Total Fertility Rate":"Total_Fertility_Rate", "Crude Birth Rate":"Crude_Birth_Rate", "Life Expectancy at Birth, Both Sexes":"Life_Expectancy_at_Birth", "Infant Mortality Rate, Both Sexes":"Infant_Mortality_Rate", "Crude Death Rate":"Crude_Death_Rate","Net Migration Rate":"Net_Migration_Rate"}, inplace = True)

# %%
# Check the previous code
country_data_df.head()
# Out:
#    Row FIPS Country_ID_Alpha Country_Name  Year  Country_Area  \
# 0    1   AF               AF  Afghanistan  1990        652230
# 1    2   AF               AF  Afghanistan  1995        652230
# 2    3   AF               AF  Afghanistan  2000        652230
# 3    4   AF               AF  Afghanistan  2005        652230
# 4    5   AF               AF  Afghanistan  2010        652230
#
#    Total_Country_Population  Annual_Growth_Rate  Rate of Natural Increase  \
# 0                  13568282              -1.928                     3.194
# 1                  19445013               3.492                     3.224
# 2                  22461349              -1.328                     3.202
# 3                  26332646               3.439                     2.496
# 4                  29116851               2.139                     2.464
#
#    Population_Density  Total_Fertility_Rate  Crude_Birth_Rate  \
# 0                20.8                8.0000             54.44
# 1                29.8                8.0000             53.23
# 2                34.4                8.0000             51.35
# 3                40.4                6.3707             41.51
# 4                44.6                5.8532             39.77
#
#    Life_Expectancy_at_Birth  Infant_Mortality_Rate  Crude_Death_Rate  \
# 0                     42.19                 167.73             22.50
# 1                     43.88                 156.75             20.99
# 2                     45.49                 146.75             19.33
# 3                     47.06                 137.56             16.55
# 4                     48.93                 127.79             15.13
#
#    Net_Migration_Rate
# 0              -51.23
# 1                2.68
# 2              -45.30
# 3                9.43
# 4               -3.25

# %%
# Reduced DF with main columns
final_columns_df = country_data_df[["Country_ID_Alpha", "Country_Name", "Year", "Total_Country_Population", "Annual_Growth_Rate", "Country_Area", "Population_Density", "Total_Fertility_Rate", "Crude_Birth_Rate", "Life_Expectancy_at_Birth", "Infant_Mortality_Rate", "Crude_Death_Rate", "Net_Migration_Rate"]]
final_columns_df.head()
# Out:
#   Country_ID_Alpha Country_Name  Year  Total_Country_Population  \
# 0               AF  Afghanistan  1990                  13568282
# 1               AF  Afghanistan  1995                  19445013
# 2               AF  Afghanistan  2000                  22461349
# 3               AF  Afghanistan  2005                  26332646
# 4               AF  Afghanistan  2010                  29116851
#
#    Annual_Growth_Rate  Country_Area  Population_Density  Total_Fertility_Rate  \
# 0              -1.928        652230                20.8                8.0000
# 1               3.492        652230                29.8                8.0000
# 2              -1.328        652230                34.4                8.0000
# 3               3.439        652230                40.4                6.3707
# 4               2.139        652230                44.6                5.8532
#
#    Crude_Birth_Rate  Life_Expectancy_at_Birth  Infant_Mortality_Rate  \
# 0             54.44                     42.19                 167.73
# 1             53.23                     43.88                 156.75
# 2             51.35                     45.49                 146.75
# 3             41.51                     47.06                 137.56
# 4             39.77                     48.93                 127.79
#
#    Crude_Death_Rate  Net_Migration_Rate
# 0             22.50              -51.23
# 1             20.99                2.68
# 2             19.33              -45.30
# 3             16.55                9.43
# 4             15.13               -3.25

# %%
# Add boolean column based on "Net_Migration_Rate"
final_columns_df["Migration_Flag"] = np.where(final_columns_df["Net_Migration_Rate"] >= 0, True, False)
final_columns_df.head()
# Out:
# <ipython-input-37-3cfcbeb81d6c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_columns_df["Migration_Flag"] = np.where(final_columns_df["Net_Migration_Rate"] >= 0, True, False)
#   Country_ID_Alpha Country_Name  Year  Total_Country_Population  \
# 0               AF  Afghanistan  1990                  13568282
# 1               AF  Afghanistan  1995                  19445013
# 2               AF  Afghanistan  2000                  22461349
# 3               AF  Afghanistan  2005                  26332646
# 4               AF  Afghanistan  2010                  29116851
#
#    Annual_Growth_Rate  Country_Area  Population_Density  Total_Fertility_Rate  \
# 0              -1.928        652230                20.8                8.0000
# 1               3.492        652230                29.8                8.0000
# 2              -1.328        652230                34.4                8.0000
# 3               3.439        652230                40.4                6.3707
# 4               2.139        652230                44.6                5.8532
#
#    Crude_Birth_Rate  Life_Expectancy_at_Birth  Infant_Mortality_Rate  \
# 0             54.44                     42.19                 167.73
# 1             53.23                     43.88                 156.75
# 2             51.35                     45.49                 146.75
# 3             41.51                     47.06                 137.56
# 4             39.77                     48.93                 127.79
#
#    Crude_Death_Rate  Net_Migration_Rate  Migration_Flag
# 0             22.50              -51.23           False
# 1             20.99                2.68            True
# 2             19.33              -45.30           False
# 3             16.55                9.43            True
# 4             15.13               -3.25           False

# %%
# Check for null values
final_columns_df.isna().sum()
# Out:
# Country_ID_Alpha              7
# Country_Name                  0
# Year                          0
# Total_Country_Population      0
# Annual_Growth_Rate          106
# Country_Area                  0
# Population_Density            0
# Total_Fertility_Rate        107
# Crude_Birth_Rate            106
# Life_Expectancy_at_Birth    107
# Infant_Mortality_Rate       107
# Crude_Death_Rate            106
# Net_Migration_Rate          106
# Migration_Flag                0
# dtype: int64

# %%
# Identify rows with NaN values
final_columns_df[final_columns_df["Country_ID_Alpha"].isna()]
# Out:
#     Country_ID_Alpha Country_Name  Year  Total_Country_Population  \
# 980              NaN      Namibia  1990                   1458648
# 981              NaN      Namibia  1995                   1661348
# 982              NaN      Namibia  2000                   1877964
# 983              NaN      Namibia  2005                   2043266
# 984              NaN      Namibia  2010                   2182968
# 985              NaN      Namibia  2015                   2388262
# 986              NaN      Namibia  2020                   2629632
#
#      Annual_Growth_Rate  Country_Area  Population_Density  \
# 980               2.990        823290                 1.8
# 981               2.461        823290                 2.0
# 982               3.238        823290                 2.3
# 983               1.221        823290                 2.5
# 984               1.399        823290                 2.7
# 985               2.008        823290                 2.9
# 986               1.834        823290                 3.2
#
#      Total_Fertility_Rate  Crude_Birth_Rate  Life_Expectancy_at_Birth  \
# 980                5.3076             37.92                     57.80
# 981                4.6200             34.98                     55.88
# 982                4.0900             33.56                     53.44
# 983                3.9345             32.46                     52.43
# 984                3.7277             30.65                     59.93
# 985                3.4294             28.36                     63.11
# 986                3.0700             25.65                     65.26
#
#      Infant_Mortality_Rate  Crude_Death_Rate  Net_Migration_Rate  \
# 980                  67.30              9.92                1.90
# 981                  66.92             10.53                0.16
# 982                  66.54             11.57               10.39
# 983                  59.49             12.68               -7.57
# 984                  46.17              9.57               -7.08
# 985                  37.82              8.28                0.00
# 986                  31.38              7.31                0.00
#
#      Migration_Flag
# 980            True
# 981            True
# 982            True
# 983           False
# 984           False
# 985            True
# 986            True

# %%
# Replace NAN values of country Namibia to "NA"
final_columns_df["Country_ID_Alpha"] = final_columns_df["Country_ID_Alpha"].fillna("NA")
final_columns_df.isna().sum()
# Out:
# <ipython-input-40-c78728f59eaa>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_columns_df["Country_ID_Alpha"] = final_columns_df["Country_ID_Alpha"].fillna("NA")
# Country_ID_Alpha              0
# Country_Name                  0
# Year                          0
# Total_Country_Population      0
# Annual_Growth_Rate          106
# Country_Area                  0
# Population_Density            0
# Total_Fertility_Rate        107
# Crude_Birth_Rate            106
# Life_Expectancy_at_Birth    107
# Infant_Mortality_Rate       107
# Crude_Death_Rate            106
# Net_Migration_Rate          106
# Migration_Flag                0
# dtype: int64

# %%
# Identify rows with NaN values
final_columns_df[final_columns_df["Annual_Growth_Rate"].isna()]
# Out:
#      Country_ID_Alpha         Country_Name  Year  Total_Country_Population  \
# 21                 AS       American Samoa  1990                     47199
# 22                 AS       American Samoa  1995                     53872
# 49                 AG  Antigua and Barbuda  1990                     64162
# 84                 AT              Austria  1990                   7722953
# 133                BE              Belgium  1990                   9969310
# ...               ...                  ...   ...                       ...
# 1554               WF    Wallis and Futuna  1990                     13476
# 1555               WF    Wallis and Futuna  1995                     14017
# 1561               XW            West Bank  1990                   1252834
# 1562               XW            West Bank  1995                   1620916
# 1568               YE                Yemen  1990                  12416080
#
#       Annual_Growth_Rate  Country_Area  Population_Density  \
# 21                   NaN           198               238.4
# 22                   NaN           198               272.1
# 49                   NaN           443               144.8
# 84                   NaN         82445                93.7
# 133                  NaN         30278               329.3
# ...                  ...           ...                 ...
# 1554                 NaN           142                94.9
# 1555                 NaN           142                98.7
# 1561                 NaN          5640               222.1
# 1562                 NaN          5640               287.4
# 1568                 NaN        527968                23.5
#
#       Total_Fertility_Rate  Crude_Birth_Rate  Life_Expectancy_at_Birth  \
# 21                     NaN               NaN                       NaN
# 22                     NaN               NaN                       NaN
# 49                     NaN               NaN                       NaN
# 84                     NaN               NaN                       NaN
# 133                    NaN               NaN                       NaN
# ...                    ...               ...                       ...
# 1554                   NaN               NaN                       NaN
# 1555                   NaN               NaN                       NaN
# 1561                   NaN               NaN                       NaN
# 1562                   NaN               NaN                       NaN
# 1568                   NaN               NaN                       NaN
#
#       Infant_Mortality_Rate  Crude_Death_Rate  Net_Migration_Rate  \
# 21                      NaN               NaN                 NaN
# 22                      NaN               NaN                 NaN
# 49                      NaN               NaN                 NaN
# 84                      NaN               NaN                 NaN
# 133                     NaN               NaN                 NaN
# ...                     ...               ...                 ...
# 1554                    NaN               NaN                 NaN
# 1555                    NaN               NaN                 NaN
# 1561                    NaN               NaN                 NaN
# 1562                    NaN               NaN                 NaN
# 1568                    NaN               NaN                 NaN
#
#       Migration_Flag
# 21             False
# 22             False
# 49             False
# 84             False
# 133            False
# ...              ...
# 1554           False
# 1555           False
# 1561           False
# 1562           False
# 1568           False
#
# [106 rows x 14 columns]

# %%
# Replace NAN values of data not available to "0"
final_columns_df = final_columns_df.fillna(0)
final_columns_df.isna().sum()
# Out:
# Country_ID_Alpha            0
# Country_Name                0
# Year                        0
# Total_Country_Population    0
# Annual_Growth_Rate          0
# Country_Area                0
# Population_Density          0
# Total_Fertility_Rate        0
# Crude_Birth_Rate            0
# Life_Expectancy_at_Birth    0
# Infant_Mortality_Rate       0
# Crude_Death_Rate            0
# Net_Migration_Rate          0
# Migration_Flag              0
# dtype: int64

# %%
# Check that the dataset has the correct data types
final_columns_df.dtypes
# Out:
# Country_ID_Alpha             object
# Country_Name                 object
# Year                          int64
# Total_Country_Population      int64
# Annual_Growth_Rate          float64
# Country_Area                  int64
# Population_Density          float64
# Total_Fertility_Rate        float64
# Crude_Birth_Rate            float64
# Life_Expectancy_at_Birth    float64
# Infant_Mortality_Rate       float64
# Crude_Death_Rate            float64
# Net_Migration_Rate          float64
# Migration_Flag                 bool
# dtype: object

# %%
# Count rows
final_columns_df["Country_ID_Alpha"].count()
# Out:
# 1589

# %%
# Check for empty values
final_columns_df.loc[final_columns_df["Net_Migration_Rate"] == 0]
# Out:
#      Country_ID_Alpha       Country_Name  Year  Total_Country_Population  \
# 21                 AS     American Samoa  1990                     47199
# 22                 AS     American Samoa  1995                     53872
# 32                 AD            Andorra  2010                     84563
# 33                 AD            Andorra  2015                     85690
# 34                 AD            Andorra  2020                     85722
# ...               ...                ...   ...                       ...
# 1554               WF  Wallis and Futuna  1990                     13476
# 1555               WF  Wallis and Futuna  1995                     14017
# 1561               XW          West Bank  1990                   1252834
# 1562               XW          West Bank  1995                   1620916
# 1568               YE              Yemen  1990                  12416080
#
#       Annual_Growth_Rate  Country_Area  Population_Density  \
# 21                 0.000           198               238.4
# 22                 0.000           198               272.1
# 32                 0.414           468               180.7
# 33                 0.120           468               183.1
# 34                -0.084           468               183.2
# ...                  ...           ...                 ...
# 1554               0.000           142                94.9
# 1555               0.000           142                98.7
# 1561               0.000          5640               222.1
# 1562               0.000          5640               287.4
# 1568               0.000        527968                23.5
#
#       Total_Fertility_Rate  Crude_Birth_Rate  Life_Expectancy_at_Birth  \
# 21                  0.0000              0.00                      0.00
# 22                  0.0000              0.00                      0.00
# 32                  1.3391             10.03                     82.88
# 33                  1.3842              8.12                     82.95
# 34                  1.4293              6.98                     83.03
# ...                    ...               ...                       ...
# 1554                0.0000              0.00                      0.00
# 1555                0.0000              0.00                      0.00
# 1561                0.0000              0.00                      0.00
# 1562                0.0000              0.00                      0.00
# 1568                0.0000              0.00                      0.00
#
#       Infant_Mortality_Rate  Crude_Death_Rate  Net_Migration_Rate  \
# 21                     0.00              0.00                 0.0
# 22                     0.00              0.00                 0.0
# 32                     3.60              5.89                 0.0
# 33                     3.58              6.92                 0.0
# 34                     3.56              7.82                 0.0
# ...                     ...               ...                 ...
# 1554                   0.00              0.00                 0.0
# 1555                   0.00              0.00                 0.0
# 1561                   0.00              0.00                 0.0
# 1562                   0.00              0.00                 0.0
# 1568                   0.00              0.00                 0.0
#
#       Migration_Flag
# 21             False
# 22             False
# 32              True
# 33              True
# 34              True
# ...              ...
# 1554           False
# 1555           False
# 1561           False
# 1562           False
# 1568           False
#
# [173 rows x 14 columns]
